# %%
import pandas as pd

# %%
loc = 'CO2-cost/data.csv'

df = pd.read_csv(loc, index_col = ['Unnamed: 0'])

df
# Out:
#      CaseNo  type  slope class armour       B      Rc       cost     CO2  \
# 0         1  CRMR   18.4     11.67 m³   5.000  10.339  234556.40  0.0411
# 1       103  CRMR   33.7     17.08 m³   5.000  11.148  127651.45  0.0384
# 2       104  CRMR   33.7     17.08 m³   6.053  11.148  136494.89  0.0282
# 3       105  CRMR   33.7     17.08 m³   6.053  11.148  135020.75  0.0304
# 4       106  CRMR   33.7     17.08 m³   6.053  11.148  130250.03  0.0390
# ..      ...   ...    ...          ...     ...     ...        ...     ...
# 155      56  CRMR   30.3     17.08 m³  10.263   9.269  149064.11  0.0310
# 156      57  CRMR   30.3     17.08 m³  10.263   9.269  147494.37  0.0334
# 157      58  CRMR   30.3     17.08 m³  10.263   9.269  142631.11  0.0422
# 158     159  CRMR   33.7     17.08 m³  25.000   4.622  136645.86  0.0339
# 159     160  CRMR   33.7     17.08 m³  25.000   4.622  132617.81  0.0421
#
#      install_duration            img
# 0             0.27646     CRMR.1.png
# ...

# %%
#df.drop('equipment', axis= 1, inplace= True)

df.to_csv(loc, index= False)
